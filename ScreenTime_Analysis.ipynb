# %% [markdown]
# <a href="https://colab.research.google.com/github/JCaesarLG/ML-Projects/blob/main/ScreenTime_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
screen = pd.read_csv(f"/content/drive/MyDrive/Raw_Data/screentime_analysis.csv")
screen.head(2)
# Out:
#          Date        App  Usage (minutes)  Notifications  Times Opened
# 0  2024-08-07  Instagram               81             24            57
# 1  2024-08-08  Instagram               90             30            53

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
screen = pd.read_csv(f"/content/drive/MyDrive/Raw_Data/screentime_analysis.csv")
screen.head(2)
# Out:
#          Date        App  Usage (minutes)  Notifications  Times Opened
# 0  2024-08-07  Instagram               81             24            57
# 1  2024-08-08  Instagram               90             30            53

# %%
screen = screen.drop(columns=['Date'], axis=1)

# %%
screen.head(2)
# Out:
#          App  Usage (minutes)  Notifications  Times Opened
# 0  Instagram               81             24            57
# 1  Instagram               90             30            53

# %%
screen.groupby('App')['Times Opened'].mean().round()
# Out:
# App
# 8 Ball Pool     7.0
# Facebook       30.0
# Instagram      42.0
# LinkedIn        5.0
# Netflix         3.0
# Safari          5.0
# WhatsApp       68.0
# X              13.0
# Name: Times Opened, dtype: float64
